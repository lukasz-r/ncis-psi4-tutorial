# %%
import numpy as np
import psi4

# %%
psi4.set_memory('2 GB')
psi4.set_num_threads(2)

ar_he_template = """Ne 0.0 0.0 0.0
--
He 0.0 0.0 10"""

# Basis set
basis_set = 'aug-cc-pVTZ'
psi4.set_options({'basis': basis_set})
mol = psi4.geometry(ar_he_template)
# Out:
#   Memory set to   1.863 GiB by Python driver.
#   Threads set to 2 by Python driver.

# %%
energy = psi4.energy('MP2', molecule=mol, bsse_type = 'cp')
# Out:
# Scratch directory: /scratch/psi4/
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   // ManyBody Setup: N-Body Levels [1, 2]//
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#         Number of 1-body computations:     2
#         Number of 2-body computations:     1
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10a1.dev84
#
#                          Git: Rev {master} ef74630
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
# ...

# %%
# list of all variables in a single calculation
for var in psi4.core.variables():
    print(f"{var}: {psi4.variable(var)}")
# Out:
# 1: 0.0
# 1CP: 0.0
# 1NOCP: 0.0
# 1VMFC: 0.0
# 1_((1, 2), (1, 2)): -131.71390598822543
# 1_((1,), (1, 2)): -128.81909122244312
# 1_((2,), (1, 2)): -2.894814852366539
# 2: 8.658423666929593e-08
# 2CP: 8.658423666929593e-08
# 2NOCP: 0.0
# 2VMFC: 0.0
# CP-CORRECTED 2-BODY CONTRIBUTION TO ENERGY: 8.658423666929593e-08
# CP-CORRECTED INTERACTION ENERGY: 8.658423666929593e-08
# CP-CORRECTED INTERACTION ENERGY THROUGH 2-BODY: 8.658423666929593e-08
# CP-CORRECTED TOTAL ENERGY THROUGH 1-BODY: 0.0
# CP-CORRECTED TOTAL ENERGY THROUGH 2-BODY: 8.658423666929593e-08
# CURRENT ENERGY: 8.658423666929593e-08
# N-BODY (1)@(1, 2) TOTAL ENERGY: -128.81909122244312
# N-BODY (1, 2)@(1, 2) TOTAL ENERGY: -131.71390598822543
# N-BODY (2)@(1, 2) TOTAL ENERGY: -2.894814852366539
# NBODY NUMBER: 3.0
# NUCLEAR REPULSION ENERGY: 1.05835442134

# %%
import numpy as np
import psi4

psi4.set_memory('2 GB')
psi4.set_num_threads(2)

ar_he_template = """ 
1 1
Li 0.0 0.0 0.0
--
0 1
He 0.0 0.0 5.5
units bohr
"""

# Basis set
basis_set = 'aug-cc-pVTZ'
psi4.set_options({'basis': basis_set})
mol = psi4.geometry(ar_he_template)

energy = psi4.energy('MP2', molecule=mol, bsse_type = 'cp')
# Out:
#   Memory set to   1.863 GiB by Python driver.
#   Threads set to 2 by Python driver.
#
# Scratch directory: /scratch/psi4/
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   // ManyBody Setup: N-Body Levels [1, 2]//
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#         Number of 1-body computations:     2
#         Number of 2-body computations:     1
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10a1.dev84
#
#                          Git: Rev {master} ef74630
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
# ...

# %%
import numpy as np
import psi4

psi4.set_memory('2 GB')
psi4.set_num_threads(2)

ar_he_template = """ 
1 1
Li 0.0 0.0 0.0
--
0 1
He 0.0 0.0 5.5
units bohr
"""

# Basis set
basis_set = 'aug-cc-pVDZ'
psi4.set_options({'basis': basis_set})
mol = psi4.geometry(ar_he_template)

energy = psi4.energy('MP2', molecule=mol, bsse_type = 'cp')
# Out:
#   Memory set to   1.863 GiB by Python driver.
#   Threads set to 2 by Python driver.
#
# Scratch directory: /scratch/psi4/
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   // ManyBody Setup: N-Body Levels [1, 2]//
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#         Number of 1-body computations:     2
#         Number of 2-body computations:     1
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10a1.dev84
#
#                          Git: Rev {master} ef74630
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
# ...

# %%
import numpy as np
import psi4

psi4.set_memory('2 GB')
psi4.set_num_threads(2)

ar_he_template = """ 
1 1
Li 0.0 0.0 5.0
--
0 1
He 0.0 0.0 10
units bohr
"""

# Basis set
basis_set = 'aug-cc-pVTZ'
psi4.set_options({'basis': basis_set, 'e_convergence':1e-9})
mol = psi4.geometry(ar_he_template)

energy = psi4.energy('SAPTO', molecule=mol, bsse_type = 'cp')
# Out:
#   Memory set to   1.863 GiB by Python driver.
#   Threads set to 2 by Python driver.
#
# Scratch directory: /scratch/psi4/
# ---------------------------------------------------------------------------
# MissingMethodError                        Traceback (most recent call last)
# Cell In[1], line 21
#      18 psi4.set_options({'basis': basis_set, 'e_convergence':1e-9})
#      19 mol = psi4.geometry(ar_he_template)
# ---> 21 energy = psi4.energy('SAPTO', molecule=mol, bsse_type = 'cp')
#
# File /opt/psi4/lib/psi4/driver/driver.py:452, in energy(name, **kwargs)
#     449     kwargs['basis'] = '(auto)'
#     451 # Are we planning?
# --> 452 plan = task_planner.task_planner("energy", lowername, molecule, **kwargs)
#     453 logger.debug('ENERGY PLAN')
#     454 logger.debug(pp.pformat(plan.dict()))
#
# File /opt/psi4/lib/psi4/driver/task_planner.py:235, in task_planner(driver, method, molecule, **kwargs)
#     225         plan.build_tasks(FiniteDifferenceComputer,
# ...
